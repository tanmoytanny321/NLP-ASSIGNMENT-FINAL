# %%
import json
import csv
import pandas as pd
import numpy as np

# %%
with open('Client_data.json') as dataframe:
    data = json.load(dataframe)

# %%
data
# Out:
# [{'_index': 'complaint-public-v2',
#   '_type': 'complaint',
#   '_id': '3211475',
#   '_score': 0.0,
#   '_source': {'tags': None,
#    'zip_code': '90301',
#    'complaint_id': '3211475',
#    'issue': 'Attempts to collect debt not owed',
#    'date_received': '2019-04-13T12:00:00-05:00',
#    'state': 'CA',
#    'consumer_disputed': 'N/A',
#    'product': 'Debt collection',
#    'company_response': 'Closed with explanation',
#    'company': 'JPMORGAN CHASE & CO.',
#    'submitted_via': 'Web',
#    'date_sent_to_company': '2019-04-13T12:00:00-05:00',
#    'company_public_response': None,
#    'sub_product': 'Credit card debt',
#    'timely': 'Yes',
#    'complaint_what_happened': '',
#    'sub_issue': 'Debt is not yours',
#    'consumer_consent_provided': 'Consent not provided'}},
#  {'_index': 'complaint-public-v2',
#   '_type': 'complaint',
#   '_id': '3229299',
#   '_score': 0.0,
#   '_source': {'tags': 'Servicemember',
#    'zip_code': '319XX',
#    'complaint_id': '3229299',
# ...

# %%
df=pd.json_normalize(data)
df
# Out:
#                     _index      _type      _id  _score   _source.tags  \
# 0      complaint-public-v2  complaint  3211475     0.0           None
# 1      complaint-public-v2  complaint  3229299     0.0  Servicemember
# 2      complaint-public-v2  complaint  3199379     0.0           None
# 3      complaint-public-v2  complaint  2673060     0.0           None
# 4      complaint-public-v2  complaint  3203545     0.0           None
# ...                    ...        ...      ...     ...            ...
# 78308  complaint-public-v2  complaint  3105617     0.0           None
# 78309  complaint-public-v2  complaint  3091984     0.0           None
# 78310  complaint-public-v2  complaint  3133355     0.0           None
# 78311  complaint-public-v2  complaint  3110963     0.0           None
# 78312  complaint-public-v2  complaint  2001189     0.0           None
#
#       _source.zip_code _source.complaint_id  \
# 0                90301              3211475
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78313 entries, 0 to 78312
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _index                             78313 non-null  object
#  1   _type                              78313 non-null  object
#  2   _id                                78313 non-null  object
#  3   _score                             78313 non-null  float64
#  4   _source.tags                       10900 non-null  object
#  5   _source.zip_code                   71556 non-null  object
#  6   _source.complaint_id               78313 non-null  object
#  7   _source.issue                      78313 non-null  object
#  8   _source.date_received              78313 non-null  object
#  9   _source.state                      76322 non-null  object
#  10  _source.consumer_disputed          78313 non-null  object
# ...

# %%
df.head()
# Out:
#                 _index      _type      _id  _score   _source.tags  \
# 0  complaint-public-v2  complaint  3211475     0.0           None
# 1  complaint-public-v2  complaint  3229299     0.0  Servicemember
# 2  complaint-public-v2  complaint  3199379     0.0           None
# 3  complaint-public-v2  complaint  2673060     0.0           None
# 4  complaint-public-v2  complaint  3203545     0.0           None
#
#   _source.zip_code _source.complaint_id                       _source.issue  \
# 0            90301              3211475   Attempts to collect debt not owed
# 1            319XX              3229299     Written notification about debt
# 2            77069              3199379  Other features, terms, or problems
# 3            48066              2673060      Trouble during payment process
# 4            10473              3203545                    Fees or interest
#
#        _source.date_received _source.state  ... _source.company_response  \
# ...

# %%
df2 = df[['_source.complaint_what_happened']].apply(lambda x: x.str.strip()).replace('', np.nan)
print(df2)
# Out:
#                          _source.complaint_what_happened
# 0                                                    NaN
# 1      Good morning my name is XXXX XXXX and I apprec...
# 2      I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 78308                                                NaN
# 78309  On Wednesday, XX/XX/XXXX I called Chas, my XXX...
# 78310  I am not familiar with XXXX pay and did not un...
# 78311  I have had flawless credit for 30 yrs. I've ha...
# 78312  Roughly 10+ years ago I closed out my accounts...
#
# [78313 rows x 1 columns]

# %%
df2.shape
# Out:
# (78313, 1)

# %%
df3=df2.dropna()
df3
# Out:
#                          _source.complaint_what_happened
# 1      Good morning my name is XXXX XXXX and I apprec...
# 2      I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 10     Chase Card was reported on XX/XX/2019. However...
# 11     On XX/XX/2018, while trying to book a XXXX  XX...
# 14     my grand son give me check for {$1600.00} i de...
# ...                                                  ...
# 78303  After being a Chase Card customer for well ove...
# 78309  On Wednesday, XX/XX/XXXX I called Chas, my XXX...
# 78310  I am not familiar with XXXX pay and did not un...
# 78311  I have had flawless credit for 30 yrs. I've ha...
# 78312  Roughly 10+ years ago I closed out my accounts...
#
# [21072 rows x 1 columns]

# %%
df3['_source.complaint_what_happened'] = df3['_source.complaint_what_happened'].astype(str)
# Out:
# C:\Users\tanmoy_kundu1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3['_source.complaint_what_happened'] = df3['_source.complaint_what_happened'].str.replace('[^\\w\\s]','')
# Out:
# C:\Users\tanmoy_kundu1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# C:\Users\tanmoy_kundu1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.columns=['main clean data']

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tanmoy_kundu1\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop = stopwords.words('english')
df3['main clean data'] = df3['main clean data'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# Out:
# C:\Users\tanmoy_kundu1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df3
# Out:
#                                          main clean data
# 1      Good morning name XXXX XXXX I appreciate could...
# 2      I upgraded XXXX XXXX card XXXX2018 told agent ...
# 10     Chase Card reported XXXX2019 However fraudulen...
# 11     On XXXX2018 trying book XXXX XXXX ticket I cam...
# 14     grand son give check 160000 deposit chase acco...
# ...                                                  ...
# 78303  After Chase Card customer well decade offered ...
# 78309  On Wednesday XXXXXXXX I called Chas XXXX XXXX ...
# 78310  I familiar XXXX pay understand great risk prov...
# 78311  I flawless credit 30 yrs Ive Chase credit card...
# 78312  Roughly 10 years ago I closed accounts JP Morg...
#
# [21072 rows x 1 columns]

# %%
from nltk.stem import WordNetLemmatizer
import re

# %%
le= WordNetLemmatizer()

# %%
def tokenize(review):
    corpus = []
    for item in review:
        x = str(item).lower()
        x = re.sub('[^a-zA-Z]',' ', x)
        x = x.split()
        x = [le.lemmatize(word) for word in x]
        corpus.append(' '.join(str(i) for i in x))
    return corpus

# %%
df3['main clean data'] = tokenize(df3['main clean data'])
# Out:
# C:\Users\tanmoy_kundu1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3
# Out:
#                                          main clean data
# 1      good morning name xxxx xxxx i appreciate could...
# 2      i upgraded xxxx xxxx card xxxx told agent upgr...
# 10     chase card reported xxxx however fraudulent ap...
# 11     on xxxx trying book xxxx xxxx ticket i came ac...
# 14     grand son give check deposit chase account fun...
# ...                                                  ...
# 78303  after chase card customer well decade offered ...
# 78309  on wednesday xxxxxxxx i called chas xxxx xxxx ...
# 78310  i familiar xxxx pay understand great risk prov...
# 78311  i flawless credit yr ive chase credit card cha...
# 78312  roughly year ago i closed account jp morgan ch...
#
# [21072 rows x 1 columns]

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
 from sklearn.feature_extraction.text import CountVectorizer as countVectorizer

# %%
wordcloud = WordCloud(max_font_size=60, max_words=40, 
                      background_color="black", random_state=100 
                      ).generate(str(df3['main clean data']))
plt.figure(figsize=[15,15])
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer as countVectorizer
def get_top_ngrams(text, n=None, ngram=(1,1)):
  vec = countVectorizer(stop_words='english', ngram_range=ngram).fit(text)
  bagofwords = vec.transform(text)
  sum_words = bagofwords.sum(axis=0)
  words_frequency = [(word, sum_words[0, index]) for word, index in vec.vocabulary_.items()]
  words_frequency = sorted(words_frequency, key = lambda x: x[1], reverse=True)
  return words_frequency[:n]

# %%
top_30words = get_top_ngrams(df3['main clean data'].values.astype('U'), n=30, ngram=(1,1))
df_unigram = pd.DataFrame(top_30words, columns=['unigram', 'count'])
df_unigram
# Out:
#         unigram   count
# 0          xxxx  202825
# 1         chase   80396
# 2       account   48627
# 3        credit   33106
# 4          card   30533
# 5      xxxxxxxx   29280
# 6          bank   28242
# 7       payment   21183
# 8          told   16380
# 9          time   16051
# 10       called   13405
# 11       charge   13337
# 12          day   13248
# 13     received   12862
# 14        money   11962
# 15        check   11794
# 16         loan   10989
# 17         said   10883
# 18       letter    9679
# 19  information    9660
# 20          fee    8961
# 21  transaction    8670
# 22       number    8617
# 23        month    8523
# 24       report    8473
# 25         year    8400
# 26         sent    8329
# 27     mortgage    8184
# 28     customer    8164
# 29          pay    7950

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=[20,6])
sns.barplot(x=df_unigram['unigram'], y=df_unigram['count'])
plt.xticks(rotation=45)
plt.xlabel("Unigram")
plt.ylabel("Count")
plt.title("Count of top 30 Unigrams")
plt.show()

# %%
top_30words = get_top_ngrams(df3['main clean data'].values.astype('U'), n=30, ngram=(3,3))
df_trigram = pd.DataFrame(top_30words, columns=['trigram', 'count'])
df_trigram
# Out:
#                        trigram  count
# 0               xxxx xxxx xxxx  40487
# 1              jp morgan chase   2351
# 2            chase credit card   2090
# 3              xxxx xxxx chase   1743
# 4           xxxxxxxx xxxx xxxx   1656
# 5           xxxx xxxx xxxxxxxx   1346
# 6              chase xxxx xxxx   1178
# 7              chase bank xxxx   1108
# 8            account xxxx xxxx   1056
# 9           xxxx xxxxxxxx xxxx   1009
# 10         credit card account    969
# 11         credit card company    961
# 12              bank xxxx xxxx    897
# 13            xxxx credit card    881
# 14             xxxx chase bank    804
# 15           xxxx xxxx account    802
# 16           credit card chase    732
# 17           morgan chase bank    677
# 18  xxxxxxxx xxxxxxxx xxxxxxxx    669
# 19          account chase bank    637
# 20          xxxx xxxx received    634
# 21            credit card xxxx    611
# 22            called xxxx xxxx    599
# 23      chase customer service    574
# ...

# %%
plt.figure(figsize=[20,6])
sns.barplot(x=df_trigram['trigram'], y=df_trigram['count'])
plt.xticks(rotation=45)
plt.xlabel("Trigram")
plt.ylabel("Count")
plt.title("Count of top 30 Trigrams")
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
tfidf = TfidfVectorizer(min_df=2, max_df=0.95, stop_words='english')

# %%
dtm = tfidf.fit_transform(df3['main clean data'])

# %%
dtm
# Out:
# <21072x14258 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1312260 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import NMF

# %%
num_topics = 5
nmf_model = NMF(n_components=num_topics, random_state=40)
nmf_model.fit(dtm)
len(tfidf.get_feature_names())
# Out:
# C:\Users\tanmoy_kundu1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# C:\Users\tanmoy_kundu1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 14258

# %%
H = nmf_model.components_

# %%
words = np.array(tfidf.get_feature_names())
topic_words = pd.DataFrame(np.zeros((num_topics, 15)), index=[f'Topic {i + 1}' for i in range(num_topics)],
                           columns=[f'Word {i + 1}' for i in range(15)]).astype(str)
for i in range(num_topics):
    ix = H[i].argsort()[::-1][:15]
    topic_words.iloc[i] = words[ix]

topic_words
# Out:
#            Word 1  Word 2    Word 3   Word 4     Word 5        Word 6  \
# Topic 1      xxxx    bank     chase   number  complaint  xxxxxxxxxxxx
# Topic 2   account   check      bank    chase      money          fund
# Topic 3    credit    card    report  inquiry      chase       account
# Topic 4   payment    loan  mortgage     late      chase      xxxxxxxx
# Topic 5  xxxxxxxx  charge     chase  dispute       card   transaction
#
#            Word 7        Word 8     Word 9   Word 10  Word 11   Word 12  \
# Topic 1      sent        morgan      email      help  address        jp
# Topic 2  checking        closed    deposit      told   branch       day
# Topic 3      hard         score  reporting   balance  company     limit
# Topic 4     month  modification       home      paid      pay      year
# Topic 5     claim      merchant      fraud  received   called  purchase
#
#           Word 13    Word 14     Word 15
# Topic 1  document       debt       money
# ...

# %%
topic_results = nmf_model.transform(dtm)

# %%
df3['Topic'] = topic_results.argmax(axis=1)
# Out:
# C:\Users\tanmoy_kundu1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.head()
# Out:
#                                       main clean data  Topic
# 1   good morning name xxxx xxxx i appreciate could...      0
# 2   i upgraded xxxx xxxx card xxxx told agent upgr...      0
# 10  chase card reported xxxx however fraudulent ap...      2
# 11  on xxxx trying book xxxx xxxx ticket i came ac...      2
# 14  grand son give check deposit chase account fun...      1

# %%
df_clean_5=df3.groupby('Topic').head(5)
df_clean_5.sort_values('Topic')
# Out:
#                                       main clean data  Topic
# 1   good morning name xxxx xxxx i appreciate could...      0
# 2   i upgraded xxxx xxxx card xxxx told agent upgr...      0
# 73  i wired one chase branch xxxx xxxx exact reins...      0
# 48  jp morgan chase bank please answer following q...      0
# 40  xxxx xxxx sofa love seat table chair never del...      0
# 30  to may concern chase bank charged wrongly over...      1
# 24                mishandling account chase auto xxxx      1
# 27  i opened account chase bank xxxx used code xxx...      1
# 17  with notice jp morgan chase restricted account...      1
# 14  grand son give check deposit chase account fun...      1
# 23  i chase credit card incorrectly reporting data...      2
# 26  i reached xxxx several time attempt fraudulent...      2
# 15                          can please remove inquiry      2
# 10  chase card reported xxxx however fraudulent ap...      2
# ...

# %%
Topic_names = { 0:"Banking services", 1:"card", 2:"Others",
               3:"Fraudalent reporting", 4:"loans" }
#Replace Topics with Topic Names
df3['Topic'] = df3['Topic'].map(Topic_names)
# Out:
# C:\Users\tanmoy_kundu1\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df3.shape
# Out:
# (21072, 2)

# %%
df3.head()
# Out:
#                                       main clean data             Topic
# 1   good morning name xxxx xxxx i appreciate could...  Banking services
# 2   i upgraded xxxx xxxx card xxxx told agent upgr...  Banking services
# 10  chase card reported xxxx however fraudulent ap...            Others
# 11  on xxxx trying book xxxx xxxx ticket i came ac...            Others
# 14  grand son give check deposit chase account fun...              card

# %%
training_data = df3[['main clean data', 'Topic']]

# %%
training_data
# Out:
#                                          main clean data                 Topic
# 1      good morning name xxxx xxxx i appreciate could...      Banking services
# 2      i upgraded xxxx xxxx card xxxx told agent upgr...      Banking services
# 10     chase card reported xxxx however fraudulent ap...                Others
# 11     on xxxx trying book xxxx xxxx ticket i came ac...                Others
# 14     grand son give check deposit chase account fun...                  card
# ...                                                  ...                   ...
# 78303  after chase card customer well decade offered ...                Others
# 78309  on wednesday xxxxxxxx i called chas xxxx xxxx ...                 loans
# 78310  i familiar xxxx pay understand great risk prov...                 loans
# 78311  i flawless credit yr ive chase credit card cha...  Fraudalent reporting
# 78312  roughly year ago i closed account jp morgan ch...  Fraudalent reporting
#
# ...

# %%
import pickle
X_train_cnt = vector.fit_transform(training_data['main clean data'])
pickle.dump(vect.vocabulary, open("count_vector.pk1", "wb"))

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_cnt)
pickle.dump(tfidf_transformer, open('tfidf.pk1', "wb"))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data['Topic'], test_size=0.25, random_state=42)

# %%
LR = LogisticRegression(random_state=42, solver='liblinear').fit(X_train, y_train)

# %%
LR.score(X_test, y_test)
# Out:
# 0.9510250569476082

# %%
y_pred = LR.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import plot_roc_curve

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[1068   22   11   26   19]
#  [   6  938   13    4    1]
#  [   8    6  974    5    7]
#  [  12   11   11 1187    8]
#  [  28   13   23   24  843]]

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax = sns.heatmap(confusion_matrix(y_test, y_pred),
                 annot=True,
                 cbar=False,
                 cmap="RdYlGn", fmt = '0.1f')
plt.xlabel("Actual label")
plt.ylabel("Predicted label")
plt.show()

# %%
Topicnames_target = ["Banking services", "loans", "Fraudalent reporting", "Card", "others"]

# %%
print(classification_report(y_test, y_pred, target_names = Topicnames_target))
# Out:
#                       precision    recall  f1-score   support
#
#     Banking services       0.95      0.93      0.94      1146
#                loans       0.95      0.98      0.96       962
# Fraudalent reporting       0.94      0.97      0.96      1000
#                 Card       0.95      0.97      0.96      1229
#               others       0.96      0.91      0.93       931
#
#             accuracy                           0.95      5268
#            macro avg       0.95      0.95      0.95      5268
#         weighted avg       0.95      0.95      0.95      5268

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data['Topic'], test_size=0.25, random_state=42)

# %%
dt = DecisionTreeClassifier(random_state=42).fit(X_train, y_train)

# %%
dt.score(X_test, y_test)
# Out:
# 0.7748671222475323

# %%
y_pred = dt.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[905  60  36  63  82]
#  [ 54 773  40  39  56]
#  [ 46  23 815  53  63]
#  [ 84  38  53 965  89]
#  [ 95  45  80  87 624]]

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax = sns.heatmap(confusion_matrix(y_test, y_pred),
                 annot=True,
                 cbar=False,
                 cmap="RdYlGn", fmt = '0.1f')
plt.xlabel("Actual label")
plt.ylabel("Predicted label")
plt.show()

# %%
Topicnames_target = ["Banking services", "loans", "Fraudalent reporting", "Card", "others"]
print(classification_report(y_test, y_pred, target_names = Topicnames_target))
# Out:
#                       precision    recall  f1-score   support
#
#     Banking services       0.76      0.79      0.78      1146
#                loans       0.82      0.80      0.81       962
# Fraudalent reporting       0.80      0.81      0.81      1000
#                 Card       0.80      0.79      0.79      1229
#               others       0.68      0.67      0.68       931
#
#             accuracy                           0.77      5268
#            macro avg       0.77      0.77      0.77      5268
#         weighted avg       0.77      0.77      0.77      5268

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data['Topic'], test_size=0.25, random_state=42)
rf = RandomForestClassifier(random_state=42).fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.8046697038724373

# %%
y_pred = rf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 750  109   63  149   75]
#  [  30  851   35   36   10]
#  [  26   29  863   35   47]
#  [  29   24   37 1127   12]
#  [  71   38   64  110  648]]

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax = sns.heatmap(confusion_matrix(y_test, y_pred),
                 annot=True,
                 cbar=False,
                 cmap="RdYlGn", fmt = '0.1f')
plt.xlabel("Actual label")
plt.ylabel("Predicted label")
plt.show()

# %%
Topicnames_target =  ["Banking services", "loans", "Fraudalent reporting", "Card", "others"]

# %%
print(classification_report(y_test, y_pred, target_names = Topicnames_target))
# Out:
#                       precision    recall  f1-score   support
#
#     Banking services       0.83      0.65      0.73      1146
#                loans       0.81      0.88      0.85       962
# Fraudalent reporting       0.81      0.86      0.84      1000
#                 Card       0.77      0.92      0.84      1229
#               others       0.82      0.70      0.75       931
#
#             accuracy                           0.80      5268
#            macro avg       0.81      0.80      0.80      5268
#         weighted avg       0.81      0.80      0.80      5268
